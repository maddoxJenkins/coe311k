# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 2*np.pi, 50)

plt.subplot(2, 3, 1) 
plt.scatter(x, np.sin(x))
plt.subplot(2, 3, 2)
plt.hist(x, 50)
plt.subplot(2,3,3)
plt.plot(x, np.tan(x))
plt.subplot(2,3,4)
sizes = x
plt.pie(x)
plt.show()
