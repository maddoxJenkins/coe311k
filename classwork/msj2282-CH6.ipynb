# %%
import numpy as np
import time

A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)

b = np.array([14, 22, 33, 26, 22], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    start_time = time.time()
    
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1, time.time() - start_time
        x = x_new
        
    return x, max_iterations, time.time() - start_time

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    start_time = time.time()
    
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k + 1, time.time() - start_time
        x = x_new
        
    return x, max_iterations, time.time() - start_time

j_sol, j_iter, j_time = jacobi(A, b, x0, tol, max_iterations)
gs_sol, gs_iter, gs_time = gauss_seidel(A, b, x0, tol, max_iterations)

print(f"Jacobi: {j_iter} iterations, Time: {j_time:.6f}s")
print(f"Gauss-Seidel: {gs_iter} iterations, Time: {gs_time:.6f}s")
# Out:
# Jacobi: 100 iterations, Time: 0.005939s
# Gauss-Seidel: 100 iterations, Time: 0.005101s

# %% [markdown]
# Used gemini to help implement the time functions.
